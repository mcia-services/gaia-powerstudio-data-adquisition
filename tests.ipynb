# %%
import logging
import src.powerstudio_gateway as powerstudio_gateway


logging.getLogger().setLevel(logging.DEBUG)

# Create gateway object to connect to PowerStudio
gateway = powerstudio_gateway.PowerStudioGateway("http://registrador.upc.edu:80")

gateway.import_tags("./tags_powerstudio.txt")

# %%
gateway.variable_ids
# Out:
# ['CT TR14 Climatitz 1.AI1',
#  'CT TR14 Climatitz 1.AI2',
#  'CT TR14 Climatitz 1.AI3',
#  'CT TR14 Climatitz 1.ANI',
#  'CT TR14 Climatitz 1.DAI1',
#  'CT TR14 Climatitz 1.DAI2',
#  'CT TR14 Climatitz 1.DAI3',
#  'CT TR14 Climatitz 1.VAI',
#  'CT TR14 Climatitz 1.API',
#  'CT TR14 Climatitz 1.CPI',
#  'CT TR14 Climatitz 1.IPI',
#  'CT TR14 Climatitz 1.COSI',
#  'CT TR14 Climatitz 1.VAE',
#  'CT TR14 Climatitz 1.AE',
#  'CT TR14 Climatitz 1.CE',
#  'CT TR14 Climatitz 1.IE',
#  'CT TR14 Climatitz 2.AI1',
#  'CT TR14 Climatitz 2.AI2',
#  'CT TR14 Climatitz 2.AI3',
#  'CT TR14 Climatitz 2.ANI',
#  'CT TR14 Climatitz 2.DAI1',
#  'CT TR14 Climatitz 2.DAI2',
#  'CT TR14 Climatitz 2.DAI3',
#  'CT TR14 Climatitz 2.VAI',
#  'CT TR14 Climatitz 2.API',
#  'CT TR14 Climatitz 2.CPI',
#  'CT TR14 Climatitz 2.IPI',
#  'CT TR14 Climatitz 2.COSI',
#  'CT TR14 Climatitz 2.VAE',
#  'CT TR14 Climatitz 2.AE',
#  'CT TR14 Climatitz 2.CE',
#  'CT TR14 Climatitz 2.IE',
#  'CT TR14 Refr 1.AI1',
# ...

# %%
gateway.get_tags_values()
# Out:
# {'CT TR14 Refr 1.API': 0.0,
#  'CT TR14 Refr 1.CPI': 0.0,
#  'CT TR14 Refr 1.IPI': 0.0,
#  'CT TR14 Refr 1.COSI': 1.0,
#  'CT TR14 Refr 1.VAE': 0.0,
#  'CT TR14 Refr 1.AE': 215994.175,
#  'CT TR14 Refr 1.CE': 15.757,
#  'CT TR14 Refr 1.IE': 182511.586,
#  'CT TR14 Refr 2.AI1': 1.15,
#  'CT TR14 Refr 2.AI2': 1.6,
#  'CT TR14 Refr 2.AI3': 1.15,
#  'CT TR14 Refr 2.ANI': 3.15,
#  'CT TR14 Refr 2.DAI1': 95.6,
#  'CT TR14 Refr 2.DAI2': 59.9,
#  'CT TR14 Refr 2.DAI3': 98.9,
#  'CT TR14 Refr 2.VAI': 0.9,
#  'CT TR14 Refr 2.API': 0.0,
#  'CT TR14 Refr 2.CPI': 0.0,
#  'CT TR14 Refr 2.IPI': 0.0,
#  'CT TR14 Refr 2.COSI': 1.0,
#  'CT TR14 Refr 2.VAE': 0.0,
#  'CT TR14 Refr 2.AE': 225492.172,
#  'CT TR14 Refr 2.CE': 10.908,
#  'CT TR14 Refr 2.IE': 186388.527,
#  'CT TR14 Bomba Calor 1.AI1': 1.3,
#  'CT TR14 Bomba Calor 1.AI2': 0.85,
#  'CT TR14 Bomba Calor 1.AI3': 0.9,
#  'CT TR14 Bomba Calor 1.ANI': 1.2,
#  'CT TR14 Bomba Calor 1.DAI1': 84.5,
#  'CT TR14 Bomba Calor 1.DAI2': 99.3,
# ...
